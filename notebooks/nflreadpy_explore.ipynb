# %%
from espn_api.football import League

# %%
LEAGUE_ID = 1365062471
SEASON_YEAR = 2025
# Credits to user for providing these
SWID = "{D2241401-9D06-46E7-84DB-B5878BA69DBD}"
ESPN_S2 = "AEA6s487YT1GrFEFWnpw0MpjPtXYDjNQ%2Fn%2FD%2B9A2GMwtEY5lnL%2B3rrL9bwWJX6oxs8gS4%2B3QBkDBRTCtVxeFc1SWRGYAbSZps5Jp1qFQJqWLO8KzdwVRKrIYVChYEQHqVEydsFdM30uIc3%2BFeGxjcIWln7nOJg8BFIDt0TJAhJpA6a8RgAcx9xZxIraTaia7z%2F1VXAytigfjLKy7ErgnA9SuojVObO5wsx852FuWL4K0PMl9VfIpSaVkVyq9KWtIdAmPANB4EM7boPSO9YhXrx%2FBasgmSITqBgOMzZNeJpKe4E3RX%2F1NpJmg7nmebZLcLpmdnF0Da807qmpHG5Qwfz93"

DB_PATH = "sqlite:///data/nfl.db"

league = League(league_id=LEAGUE_ID, year=SEASON_YEAR, espn_s2=ESPN_S2, swid=SWID)

# %%
len(league.player_map)
# Out:
# 5437

# %%
help(League)
# Out:
# Help on class League in module espn_api.football.league:
#
# class League(espn_api.base_league.BaseLeague)
#  |  League(
#  |      league_id: int,
#  |      year: int,
#  |      espn_s2=None,
#  |      swid=None,
#  |      fetch_league=True,
#  |      debug=False
#  |  )
#  |
#  |  Creates a League instance for Public/Private ESPN league
#  |
#  |  Method resolution order:
#  |      League
#  |      espn_api.base_league.BaseLeague
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(
#  |      self,
#  |      league_id: int,
#  |      year: int,
#  |      espn_s2=None,
#  |      swid=None,
#  |      fetch_league=True,
#  |      debug=False
#  |  )
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  box_scores(self, week: int = None) -> List[espn_api.football.box_score.BoxScore]
#  |      Returns list of box score for a given week
#  |
#  |      Should only be used with most recent season
#  |
#  |  fetch_league(self)
#  |
#  |  free_agents(
#  |      self,
#  |      week: int = None,
#  |      size: int = 50,
#  |      position: str = None,
#  |      position_id: int = None
#  |  ) -> List[espn_api.football.player.Player]
#  |      Returns a List of Free Agents for a Given Week
#  |
#  |      Should only be used with most recent season
#  |
#  |  least_scored_week(self) -> Tuple[espn_api.football.team.Team, int]
#  |
#  |  least_scorer(self) -> espn_api.football.team.Team
#  |
#  |  load_roster_week(self, week: int) -> None
#  |      Sets Teams Roster for a Certain Week
#  |
#  |  message_board(self, msg_types: List[str] = None)
#  |      Returns a list of league messages
#  |
#  |  most_points_against(self) -> espn_api.football.team.Team
#  |
#  |  player_info(self, name: str = None, playerId: Union[int, list] = None) -> Union[espn_api.football.player.Player, List[espn_api.football.player.Player]]
#  |      Returns Player class if name found
#  |
#  |  power_rankings(self, week: int = None)
#  |      Return power rankings for any week
#  |
#  |  recent_activity(self, size: int = 25, msg_type: str = None, offset: int = 0) -> List[espn_api.football.activity.Activity]
#  |      Returns a list of recent league activities (Add, Drop, Trade)
#  |
#  |  refresh(self)
#  |      Gets latest league data. This can be used instead of creating a new League class each week
#  |
#  |  refresh_draft(self, refresh_players=False, refresh__teams=False)
#  |
#  |  scoreboard(self, week: int = None) -> List[espn_api.football.matchup.Matchup]
#  |      Returns list of matchups for a given week
#  |
#  |  standings(self) -> List[espn_api.football.team.Team]
#  |
#  |  standings_weekly(self, week: int) -> List[espn_api.football.team.Team]
#  |      This is the main function to get the standings for a given week.
#  |
#  |      It controls the tiebreaker hierarchy and calls the recursive League()._sort_team_data_list function.
#  |      First, the division winners must be determined. Then, the rest of the teams are sorted.
#  |
#  |      The standard tiebreaker hierarchy is:
#  |          1. Head-to-head record among the tied teams
#  |          2. Total points scored for the season
#  |          3. Division record (if all tied teams are in the same division)
#  |          4. Total points scored against for the season
#  |          5. Coin flip
#  |
#  |      Args:
#  |          week (int): Week to get the standings for
#  |
#  |      Returns:
#  |          List[Dict]: Sorted standings list
#  |
#  |  top_scored_week(self) -> Tuple[espn_api.football.team.Team, int]
#  |
#  |  top_scorer(self) -> espn_api.football.team.Team
#  |
#  |  transactions(
#  |      self,
#  |      scoring_period: int = None,
#  |      types: Set[str] = {'FREEAGENT', 'WAIVER_ERROR', 'WAIVER'}
#  |  ) -> List[espn_api.football.transaction.Transaction]
#  |      Returns a list of recent transactions
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from espn_api.base_league.BaseLeague:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  get_team_data(self, team_id: int) -> List
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from espn_api.base_league.BaseLeague:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
