# %%
# Out:
# shape: (9, 40)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ gsis_id   ┆ display_n ┆ common_fi ┆ … ┆ draft_yea ┆ draft_rou ┆ draft_pic ┆ draft_te │
# │ ---       ┆ ---       ┆ ame       ┆ rst_name  ┆   ┆ r         ┆ nd        ┆ k         ┆ am       │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆ str       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 24356     ┆ 24356     ┆ 24356     ┆ … ┆ 12130.0   ┆ 12130.0   ┆ 12130.0   ┆ 12130    │
# │ null_coun ┆ 0         ┆ 0         ┆ 0         ┆ … ┆ 12226.0   ┆ 12226.0   ┆ 12226.0   ┆ 12226    │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...
